# %%
import pandas as pd

# %% [markdown]
# Load data

# %%
df=pd.read_csv('clean_data_after_eda.csv')

# %%
df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  \
# 0      2015-11-01   2015-06-23               0.00  ...
# 1      2009-08-21   2015-08-31             189.95  ...
# 2      2010-04-16   2015-04-17              47.96  ...
#
#    var_6m_price_off_peak_var  var_6m_price_peak_var  \
# 0                   0.000131           4.100838e-05
# 1                   0.000003           1.217891e-03
# ...

# %% [markdown]
# convert columns to datetime

# %%
date_columns =['date_activ','date_end','date_modif_prod','date_renewal']
for col in date_columns:
  df[col]=pd.to_datetime(df[col], format='%Y-%m-%d')

df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month date_activ   date_end  \
# 0         0         54946                0 2013-06-15 2016-06-15
# 1      4660             0                0 2009-08-21 2016-08-30
# 2       544             0                0 2010-04-16 2016-04-16
# 3      1584             0                0 2010-03-30 2016-03-30
# 4      4425             0              526 2010-01-13 2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  \
# 0      2015-11-01   2015-06-23               0.00  ...
# ...

# %% [markdown]
# remove columns with only one unique value

# %%
df = df.loc[:, df.apply(pd.Series.nunique) != 1]

# %% [markdown]
# extract new features from date columns

# %%
for col in date_columns:
    df[f"year_{col}"] = df[col].dt.year
    df[f"month_{col}"] = df[col].dt.month
    df[f"day_{col}"] = df[col].dt.day
    df[f"day_of_week_{col}"] = df[col].dt.dayofweek

# %%
df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month date_activ   date_end  \
# 0         0         54946                0 2013-06-15 2016-06-15
# 1      4660             0                0 2009-08-21 2016-08-30
# 2       544             0                0 2010-04-16 2016-04-16
# 3      1584             0                0 2010-03-30 2016-03-30
# 4      4425             0              526 2010-01-13 2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  day_date_end  \
# 0      2015-11-01   2015-06-23               0.00  ...            15
# ...

# %% [markdown]
# **Feature** **engineering**

# %%
price_df=pd.read_csv('price_data.csv')
price_df['price_date']=pd.to_datetime(price_df['price_date'],format='%Y-%m-%d')
df.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month date_activ   date_end  \
# 0         0         54946                0 2013-06-15 2016-06-15
# 1      4660             0                0 2009-08-21 2016-08-30
# 2       544             0                0 2010-04-16 2016-04-16
# 3      1584             0                0 2010-03-30 2016-03-30
# 4      4425             0              526 2010-01-13 2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  day_date_end  \
# 0      2015-11-01   2015-06-23               0.00  ...            15
# ...

# %%
monthly_price_by_id = price_df.groupby(['id', 'price_date']).agg({'price_off_peak_var': 'mean', 'price_off_peak_fix': 'mean'}).reset_index()
jan_prices = monthly_price_by_id.groupby('id').first().reset_index()
dec_prices = monthly_price_by_id.groupby('id').last().reset_index()
diff = pd.merge(dec_prices.rename(columns={'price_off_peak_var': 'dec_1', 'price_off_peak_fix': 'dec_2'}), jan_prices.drop(columns='price_date'), on='id')
diff['offpeak_diff_dec_january_energy'] = diff['dec_1'] - diff['price_off_peak_var']
diff['offpeak_diff_dec_january_power'] = diff['dec_2'] - diff['price_off_peak_fix']
diff = diff[['id', 'offpeak_diff_dec_january_energy','offpeak_diff_dec_january_power']]
diff.head()
# Out:
#                                  id  offpeak_diff_dec_january_energy  \
# 0  0002203ffbb812588b632b9e628cc38d                        -0.006192
# 1  0004351ebdd665e6ee664792efc4fd13                        -0.004104
# 2  0010bcc39e42b3c2131ed2ce55246e3c                         0.050443
# 3  0010ee3855fdea87602a5b7aba8e42de                        -0.010018
# 4  00114d74e963e47177db89bc70108537                        -0.003994
#
#    offpeak_diff_dec_january_power
# 0                        0.162916
# 1                        0.177779
# 2                        1.500000
# 3                        0.162916
# 4                       -0.000001

# %%
price_df['year'] = price_df['price_date'].dt.year
price_df['month'] = price_df['price_date'].dt.month

# %% [markdown]
# yearly aggregates

# %%
yearly_agg = price_df.groupby(['id', 'year']).agg(
    yearly_mean_off_peak_var=('price_off_peak_var', 'mean'),
    yearly_max_off_peak_var=('price_off_peak_var', 'max'),
    yearly_min_off_peak_var=('price_off_peak_var', 'min'),
    yearly_mean_off_peak_fix=('price_off_peak_fix', 'mean'),
    yearly_max_off_peak_fix=('price_off_peak_fix', 'max'),
    yearly_min_off_peak_fix=('price_off_peak_fix', 'min')
).reset_index()

print(yearly_agg)
# Out:
#                                      id  year  yearly_mean_off_peak_var  \
# 0      0002203ffbb812588b632b9e628cc38d  2015                  0.124338
# 1      0004351ebdd665e6ee664792efc4fd13  2015                  0.146426
# 2      0010bcc39e42b3c2131ed2ce55246e3c  2015                  0.181558
# 3      0010ee3855fdea87602a5b7aba8e42de  2015                  0.118757
# 4      00114d74e963e47177db89bc70108537  2015                  0.147926
# ...                                 ...   ...                       ...
# 16091  ffef185810e44254c3a4c6395e6b4d8a  2015                  0.138863
# 16092  fffac626da707b1b5ab11e8431a4d0a2  2015                  0.147137
# 16093  fffc0cacd305dd51f316424bbb08d1bd  2015                  0.153879
# 16094  fffe4f5646aa39c7f97f95ae2679ce64  2015                  0.123858
# 16095  ffff7fa066f1fb305ae285bb03bf325a  2015                  0.125360
#
#        yearly_max_off_peak_var  yearly_min_off_peak_var  \
# ...
